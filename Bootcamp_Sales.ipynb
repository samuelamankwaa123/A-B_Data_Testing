# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelamankwaa123/A-B_Data_Testing/blob/main/Bootcamp_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("bootcamp_large_dataset_with_issues.csv")

df["Sales"].fillna(df["Sales"].mean(), inplace=True)
df["Category"].fillna("Unknown", inplace=True)

df = df.drop_duplicates()

df["Category"] = df["Category"].astype("category")
df["Profit_Margin"] = df["Profit"] / df["Sales"]
df["Sales_per_unit"] = df["Sales"] / df["Quantity"]
df["Sales_Category"] = df["Sales"].apply(
    lambda x: "High" if x > 3000 else "Medium" if x > 1000 else "Low"
)

df_filtered = df[df["Profit"] > 0]

df.to_csv("cleaned_data.csv", index=False)

from google.colab import files
files.download("cleaned_data.csv")
# Out:
# /tmp/ipykernel_5796/2734396518.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Sales"].fillna(df["Sales"].mean(), inplace=True)
# /tmp/ipykernel_5796/2734396518.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...
